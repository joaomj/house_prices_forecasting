# %% [markdown]
# # **Análise Exploratória**

# %% [markdown]
# - Inspecionar o dataset
# - Estatísticas descritivas
# - Distribuição de dados (esp. target)
# - Pré-tratamento de dados p/efetuar análises, extrair insights (correlações, etc)

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import numpy as np

#from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Configuração de exibição do Pandas

# %%
# Configurar pandas para não exibir números em notação científica
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Configurar pandas para exibir todas as colunas
pd.options.display.max_columns=4000
pd.options.display.max_rows = 999

# %% [markdown]
# ## Funções

# %%
# Função para ler ou gravar dados no banco SQL
def manage_db(operation, table_name, db_path, df=None):
    """
    Função para ler ou gravar dados no banco de dados SQLite 'house_prices.db'.

    Parâmetros:
    operation (str): 'r' para ler ou 'w' para gravar.
    table_name (str): Nome da tabela para ler ou gravar.
    df (pd.DataFrame, opcional): DataFrame para gravar na tabela (necessário se operação for 'w').

    Retorna:
    pd.DataFrame se operação for 'r'. None se operação for 'w'.
    """
   
    # conecta ao banco de dados
    conn = sqlite3.connect(db_path)

    # Se for operação de leitura
    if operation == 'r':
        query = f"SELECT * FROM {table_name}"
        df = pd.read_sql(query, conn)
        conn.close()
        return df
    
    # Se for operação de escrita (salvar df)
    elif operation == 'w' and df is not None:
        df.to_sql(table_name, conn, if_exists='replace', index=False)
        conn.close()
        return None
    
    else:
        conn.close()
        raise ValueError("Operação inválida ou DataFrame não fornecido para escrita.")
# ---------------------------------------------------------------------------------------

# Função para converter os tipos das colunas do dataset
def convert_column_types(dataframe, column_types:dict):

    df = dataframe.copy()
    
    for column, dtype in column_types.items():
        df[column] = pd.to_numeric(df[column], errors='coerce') if dtype in [int, float] else df[column].astype(dtype)
    return df
# ---------------------------------------------------------------------------------------

# Função para converter as colunas especificadas para o tipo 'category'
def convert_columns_to_category(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = df[column].astype('category')
    return df
# ---------------------------------------------------------------------------------------

# Função para plotar gráficos de barras horizontais da % de valores nulos por coluna
def plot_null_percentage(df, output_file=None, min_null_percentage=1):
    """
    Plota o gráfico da porcentagem de valores nulos por coluna para um DataFrame.
    
    Parâmetros:
    df (pd.DataFrame): DataFrame para análise.
    output_file (str): Caminho do arquivo para salvar o gráfico.
    min_null_percentage (float): Porcentagem mínima de valores nulos para incluir no gráfico.
    """
    # Calcular a porcentagem de valores nulos por coluna
    null_percentage = df.isnull().mean() * 100

    # Ordenar em ordem decrescente
    null_percentage_sorted = null_percentage.sort_values(ascending=False)

    # Filtrar colunas com pelo menos min_null_percentage de valores nulos
    null_percentage_sorted = null_percentage_sorted[null_percentage_sorted >= min_null_percentage]

    # Criar DataFrame para o gráfico
    plot_data = pd.DataFrame({
        'Column': null_percentage_sorted.index,
        'Null Percentage': null_percentage_sorted.values,
        'Hue': null_percentage_sorted.index  # Adicionar coluna para hue
    })

    # Criar o gráfico de barras horizontais
    plt.figure(figsize=(9, 4))
    ax = sns.barplot(x='Null Percentage', y='Column', data=plot_data, hue='Hue', palette="viridis", legend=False)

    # Configurar o gráfico
    ax.set_title("Porcentagem de Valores Nulos por Coluna (>= {:.1f}%)".format(min_null_percentage))
    ax.set_xlabel("Porcentagem de Valores Nulos (%)")
    ax.set_ylabel("Coluna")

    # Ajustar o layout e salvar o gráfico
    plt.tight_layout()

    if output_file is not None:
        plt.savefig(output_file)
    plt.show()
    plt.close()
# ---------------------------------------------------------------------------------------

# Função para imputar valores faltantes usando o MICE
def impute_mice_and_mode(df):
    # Separar colunas numéricas e categóricas
    numeric_cols = df.select_dtypes(include=['number']).columns
    categorical_cols = df.select_dtypes(include=['object', 'category']).columns
    
    # Criar o imputador MICE (IterativeImputer)
    imputer_mice = IterativeImputer(estimator=LinearRegression(), max_iter=10, random_state=0)
    
    # Imputar valores faltantes nas colunas numéricas
    df_numeric_imputed = pd.DataFrame(imputer_mice.fit_transform(df[numeric_cols]), columns=numeric_cols, index=df.index)
    
    # Imputar valores faltantes nas colunas categóricas com moda
    df_categorical_imputed = df[categorical_cols].copy()  # Faz uma cópia do DataFrame
    for col in categorical_cols:
        mode_value = df[col].mode()[0]
        df_categorical_imputed[col] = df_categorical_imputed[col].fillna(mode_value)  # Imputa a moda
    
    # Concatenar os DataFrames imputados
    df_imputed = pd.concat([df_numeric_imputed, df_categorical_imputed], axis=1)
    
    return df_imputed
# ---------------------------------------------------------------------------------------

# Função para plotar os boxplots das cols numéricas numa grid
def plot_boxplots(df, filename):
    # Selecionar colunas numéricas
    numeric_cols = df.select_dtypes(include=['number']).columns
    
    # Número de colunas para a grid
    n_cols = 5
    n_rows = len(numeric_cols) // n_cols + (len(numeric_cols) % n_cols > 0)
    
    # Criar a figura
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))
    
    # Iterar sobre cada coluna e criar o boxplot
    for i, col in enumerate(numeric_cols):
        row = i // n_cols
        col_idx = i % n_cols
        sns.boxplot(data=df, x=col, ax=axes[row, col_idx])
        axes[row, col_idx].set_title(col)
    
    # Remover subplots vazios
    for j in range(i + 1, n_rows * n_cols):
        row = j // n_cols
        col_idx = j % n_cols
        fig.delaxes(axes[row, col_idx])
    
    plt.tight_layout()
    plt.savefig(filename)
    plt.show()
    plt.close()

# %% [markdown]
# ## Carregando dados

# %%
df_train = manage_db(operation='r', table_name='df_train', db_path='../data/house_prices.db')
df_train.head()
# Out:
#                                   Type            Region MunicipalityCode  \
# 0          Pre-owned Condominiums etc.                              13103
# 1  Residential Land(Land and Building)  Residential Area            13120
# 2          Residential Land(Land Only)  Residential Area            13201
# 3          Pre-owned Condominiums etc.                              13208
# 4          Residential Land(Land Only)  Residential Area            13117
#
#   Prefecture   Municipality      DistrictName NearestStation  \
# 0      Tokyo    Minato Ward            Kaigan      Takeshiba
# 1      Tokyo    Nerima Ward           Nishiki   Kamiitabashi
# 2      Tokyo  Hachioji City  Shimoongatamachi  Takao (Tokyo)
# 3      Tokyo     Chofu City      Kamiishiwara     Nishichofu
# 4      Tokyo      Kita Ward             Shimo          Shimo
#
#   TimeToNearestStation MinTimeToNearestStation MaxTimeToNearestStation  ...  \
# 0                    1                     1.0                     1.0  ...
# 1                   15                    15.0                    15.0  ...
# 2              1H-1H30                    60.0                    90.0  ...
# 3                   16                    16.0                    16.0  ...
# 4                    6                     6.0                     6.0  ...
#
#   Breadth                                       CityPlanning CoverageRatio  \
# 0                                      Quasi-industrial Zone          60.0
# 1     4.0  Category I Exclusively Low-story Residential Zone          60.0
# 2     4.5  Category I Exclusively Low-story Residential Zone          40.0
# 3                                      Quasi-industrial Zone          60.0
# 4     4.5  Category I Exclusively Medium-high Residential...          60.0
#
#   FloorAreaRatio            Period  Year Quarter Renovation  \
# 0          400.0  1st quarter 2011  2011       1       Done
# 1          200.0  3rd quarter 2013  2013       3
# 2           80.0  4th quarter 2007  2007       4
# 3          200.0  2nd quarter 2015  2015       2    Not yet
# 4          200.0  4th quarter 2015  2015       4
#
#                            Remarks TradePrice
# 0                                    24000000
# 1  Dealings including private road   51000000
# 2                                    14000000
# 3                                    23000000
# 4                                    33000000
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Informações Gerais do Dataset

# %% [markdown]
# - Dimensões
# - Nomenclatura de colunas
# - Estatísticas Descritivas
# - Presença de nulos, duplicados
# - Checagem de tipos
# - Outliers
# - Avaliação de Colunas

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325260 entries, 0 to 325259
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Type                         325260 non-null  object
#  1   Region                       325260 non-null  object
#  2   MunicipalityCode             325260 non-null  object
#  3   Prefecture                   325260 non-null  object
#  4   Municipality                 325260 non-null  object
#  5   DistrictName                 325260 non-null  object
#  6   NearestStation               325260 non-null  object
#  7   TimeToNearestStation         325260 non-null  object
#  8   MinTimeToNearestStation      325260 non-null  object
#  9   MaxTimeToNearestStation      325260 non-null  object
#  10  FloorPlan                    325260 non-null  object
#  11  Area                         325260 non-null  object
#  12  AreaIsGreaterFlag            325260 non-null  object
#  13  UnitPrice                    325260 non-null  object
#  14  PricePerTsubo                325260 non-null  object
#  15  LandShape                    325260 non-null  object
#  16  Frontage                     325260 non-null  object
#  17  FrontageIsGreaterFlag        325260 non-null  object
#  18  TotalFloorArea               325260 non-null  object
#  19  TotalFloorAreaIsGreaterFlag  325260 non-null  object
#  20  BuildingYear                 325260 non-null  object
#  21  PrewarBuilding               325260 non-null  object
#  22  Structure                    325260 non-null  object
#  23  Use                          325260 non-null  object
#  24  Purpose                      325260 non-null  object
#  25  Direction                    325260 non-null  object
#  26  Classification               325260 non-null  object
#  27  Breadth                      325260 non-null  object
#  28  CityPlanning                 325260 non-null  object
#  29  CoverageRatio                325260 non-null  object
#  30  FloorAreaRatio               325260 non-null  object
#  31  Period                       325260 non-null  object
#  32  Year                         325260 non-null  object
#  33  Quarter                      325260 non-null  object
#  34  Renovation                   325260 non-null  object
#  35  Remarks                      325260 non-null  object
#  36  TradePrice                   325260 non-null  object
# dtypes: object(37)
# memory usage: 91.8+ MB

# %% [markdown]
# ### Checagem de tipos

# %% [markdown]
# Todas as colunas estão no formato 'string'. Vamos convertê-las aos tipos corretos.

# %%
# Mapeando os tipos corretos das colunas
column_types = {
    'Type': str,
    'Region': str,
    'MunicipalityCode': int,
    'Prefecture': str,
    'Municipality': str,
    'DistrictName': str,
    'NearestStation': str,
    'TimeToNearestStation': str,
    'MinTimeToNearestStation': int,
    'MaxTimeToNearestStation': int,
    'FloorPlan': str,
    'Area': int,
    'AreaIsGreaterFlag': int,
    'UnitPrice': float,
    'PricePerTsubo': float,
    'LandShape': str,
    'Frontage': float,
    'FrontageIsGreaterFlag': int,
    'TotalFloorArea': int,
    'TotalFloorAreaIsGreaterFlag': int,
    'BuildingYear': int,
    'PrewarBuilding': int,
    'Structure': str,
    'Use': str,
    'Purpose': str,
    'Direction': str,
    'Classification': str,
    'Breadth': float,
    'CityPlanning': str,
    'CoverageRatio': int,
    'FloorAreaRatio': int,
    'Period': str,
    'Year': int,
    'Quarter': int,
    'Renovation': str,
    'Remarks': str,
    'TradePrice': int
}

df_train = convert_column_types(df_train, column_types)
df_train.dtypes
# Out:
# Type                            object
# Region                          object
# MunicipalityCode                 int64
# Prefecture                      object
# Municipality                    object
# DistrictName                    object
# NearestStation                  object
# TimeToNearestStation            object
# MinTimeToNearestStation        float64
# MaxTimeToNearestStation        float64
# FloorPlan                       object
# Area                             int64
# AreaIsGreaterFlag                int64
# UnitPrice                      float64
# PricePerTsubo                  float64
# LandShape                       object
# Frontage                       float64
# FrontageIsGreaterFlag          float64
# TotalFloorArea                 float64
# TotalFloorAreaIsGreaterFlag      int64
# BuildingYear                   float64
# PrewarBuilding                   int64
# Structure                       object
# Use                             object
# Purpose                         object
# Direction                       object
# Classification                  object
# Breadth                        float64
# CityPlanning                    object
# CoverageRatio                  float64
# FloorAreaRatio                 float64
# Period                          object
# Year                             int64
# Quarter                          int64
# Renovation                      object
# Remarks                         object
# TradePrice                       int64
# dtype: object

# %% [markdown]
# ### Estatística Descritiva

# %%
# estatísticas descritivas das colunas numéricas
df_train.describe().T
# Out:
#                                   count          mean            std  \
# MunicipalityCode            325260.0000    13139.8000        46.1000
# MinTimeToNearestStation     317002.0000       10.1900         7.9900
# MaxTimeToNearestStation     316879.0000       11.1200        11.6200
# Area                        325260.0000      117.1700       204.3000
# AreaIsGreaterFlag           325260.0000        0.0000         0.0600
# UnitPrice                    63585.0000   425872.3400    476035.1500
# PricePerTsubo                63585.0000  1407507.5900   1571121.5200
# Frontage                    162145.0000        9.6300         6.6100
# FrontageIsGreaterFlag            0.0000           NaN            NaN
# TotalFloorArea              109005.0000      172.8300       268.1900
# TotalFloorAreaIsGreaterFlag 325260.0000        0.0000         0.0500
# BuildingYear                251512.0000     1997.9100        14.1100
# PrewarBuilding              325260.0000        0.0000         0.0300
# Breadth                     173966.0000        6.2500         4.8700
# CoverageRatio               320607.0000       62.1500        13.1300
# FloorAreaRatio              320607.0000      265.5500       159.6700
# Year                        325260.0000     2012.5800         3.9000
# Quarter                     325260.0000        2.5000         1.1200
# TradePrice                  325260.0000 66154184.3300 324544543.4700
#
#                                    min           25%           50%  \
# MunicipalityCode            13101.0000    13110.0000    13117.0000
# MinTimeToNearestStation         0.0000        5.0000        8.0000
# MaxTimeToNearestStation         0.0000        5.0000        8.0000
# Area                           10.0000       50.0000       70.0000
# AreaIsGreaterFlag               0.0000        0.0000        0.0000
# UnitPrice                       4.0000   200000.0000   340000.0000
# PricePerTsubo                  13.0000   680000.0000  1100000.0000
# Frontage                        0.5000        5.9000        8.0000
# FrontageIsGreaterFlag              NaN           NaN           NaN
# TotalFloorArea                 10.0000       85.0000       95.0000
# TotalFloorAreaIsGreaterFlag     0.0000        0.0000        0.0000
# BuildingYear                 1945.0000     1988.0000     2001.0000
# PrewarBuilding                  0.0000        0.0000        0.0000
# Breadth                         1.0000        4.0000        5.0000
# CoverageRatio                  30.0000       60.0000       60.0000
# FloorAreaRatio                 50.0000      150.0000      200.0000
# Year                         2005.0000     2009.0000     2013.0000
# Quarter                         1.0000        1.0000        3.0000
# TradePrice                   1000.0000 21000000.0000 35000000.0000
#
#                                       75%              max
# MunicipalityCode               13201.0000       13421.0000
# MinTimeToNearestStation           13.0000         120.0000
# MaxTimeToNearestStation           13.0000         120.0000
# Area                             115.0000        5000.0000
# AreaIsGreaterFlag                  0.0000           1.0000
# UnitPrice                     540000.0000    20000000.0000
# PricePerTsubo                1800000.0000    66000000.0000
# Frontage                          11.4000          50.0000
# FrontageIsGreaterFlag                 NaN              NaN
# TotalFloorArea                   120.0000        2000.0000
# TotalFloorAreaIsGreaterFlag        0.0000           1.0000
# BuildingYear                    2009.0000        2020.0000
# PrewarBuilding                     0.0000           1.0000
# Breadth                            6.0000          85.0000
# CoverageRatio                     80.0000          80.0000
# FloorAreaRatio                   300.0000        1200.0000
# Year                            2016.0000        2019.0000
# Quarter                            3.0000           4.0000
# TradePrice                  54000000.0000 61000000000.0000

# %% [markdown]
# Algumas colunas, apesar de numéricas, na verdade representam categorias. Vamos exibir as estatísticas apenas das colunas realmente numéricas:

# %%
"""Convertendo colunas de categorias para o tipo CATEGORY
- ATENÇÃO: o Pandas não preserva o tipo category ao salvar em CSV.
- Ou seja, se você salvar em csv, depois de ler esse arquivo vai precisar fazer essa conversão para category novamente.
"""

# Lista de todas as colunas a serem convertidas para 'category'
columns_to_category = [
    'Type', 'Region', 'MunicipalityCode', 'Prefecture', 'Municipality',
    'DistrictName', 'NearestStation', 'FloorPlan', 'AreaIsGreaterFlag',
    'LandShape', 'FrontageIsGreaterFlag', 'TotalFloorAreaIsGreaterFlag',
    'BuildingYear','PrewarBuilding', 'Structure', 'Use', 'Purpose', 'Direction',
    'Classification', 'CityPlanning', 'Period', 'Year', 'Quarter', 'Renovation'
]

# Aplicar a função ao DataFrame df_train
df_train = convert_columns_to_category(df_train, columns_to_category)

# Exibir os tipos das colunas para verificar
# print(df_train.dtypes)

# %%
# estatísticas descritivas das colunas REALMENTE numéricas
df_train.describe().T
# Out:
#                               count          mean            std       min  \
# MinTimeToNearestStation 317002.0000       10.1921         7.9879    0.0000
# MaxTimeToNearestStation 316879.0000       11.1168        11.6177    0.0000
# Area                    325260.0000      117.1717       204.3001   10.0000
# UnitPrice                63585.0000   425872.3408    476035.1482    4.0000
# PricePerTsubo            63585.0000  1407507.5921   1571121.5177   13.0000
# Frontage                162145.0000        9.6299         6.6108    0.5000
# TotalFloorArea          109005.0000      172.8341       268.1946   10.0000
# Breadth                 173966.0000        6.2479         4.8746    1.0000
# CoverageRatio           320607.0000       62.1485        13.1330   30.0000
# FloorAreaRatio          320607.0000      265.5521       159.6709   50.0000
# TradePrice              325260.0000 66154184.3298 324544543.4733 1000.0000
#
#                                   25%           50%           75%  \
# MinTimeToNearestStation        5.0000        8.0000       13.0000
# MaxTimeToNearestStation        5.0000        8.0000       13.0000
# Area                          50.0000       70.0000      115.0000
# UnitPrice                 200000.0000   340000.0000   540000.0000
# PricePerTsubo             680000.0000  1100000.0000  1800000.0000
# Frontage                       5.9000        8.0000       11.4000
# TotalFloorArea                85.0000       95.0000      120.0000
# Breadth                        4.0000        5.0000        6.0000
# CoverageRatio                 60.0000       60.0000       80.0000
# FloorAreaRatio               150.0000      200.0000      300.0000
# TradePrice              21000000.0000 35000000.0000 54000000.0000
#
#                                      max
# MinTimeToNearestStation         120.0000
# MaxTimeToNearestStation         120.0000
# Area                           5000.0000
# UnitPrice                  20000000.0000
# PricePerTsubo              66000000.0000
# Frontage                         50.0000
# TotalFloorArea                 2000.0000
# Breadth                          85.0000
# CoverageRatio                    80.0000
# FloorAreaRatio                 1200.0000
# TradePrice              61000000000.0000

# %% [markdown]
# Salvando dataset com tipos corrigidos:

# %%
df_train.to_csv('../data/train1_corrected_types.csv', index=None)

# %% [markdown]
# ### Tratamento de Nulos e Duplicados

# %%
df_train = pd.read_csv('../data/train1_corrected_types.csv')

# %%
"""Convertendo colunas de categorias para o tipo CATEGORY
- ATENÇÃO: o Pandas não preserva o tipo category ao salvar em CSV.
- Ou seja, se você salvar em csv, depois de ler esse arquivo vai precisar fazer essa conversão para category novamente.
"""

# Lista de todas as colunas a serem convertidas para 'category'
columns_to_category = [
    'Type', 'Region', 'MunicipalityCode', 'Prefecture', 'Municipality',
    'DistrictName', 'NearestStation', 'FloorPlan', 'AreaIsGreaterFlag',
    'LandShape', 'FrontageIsGreaterFlag', 'TotalFloorAreaIsGreaterFlag',
    'BuildingYear','PrewarBuilding', 'Structure', 'Use', 'Purpose', 'Direction',
    'Classification', 'CityPlanning', 'Period', 'Year', 'Quarter', 'Renovation'
]

# Aplicar a função ao DataFrame df_train
df_train = convert_columns_to_category(df_train, columns_to_category)

# Exibir os tipos das colunas para verificar
print(df_train.dtypes)
# Out:
# Type                           category
# Region                         category
# MunicipalityCode               category
# Prefecture                     category
# Municipality                   category
# DistrictName                   category
# NearestStation                 category
# TimeToNearestStation             object
# MinTimeToNearestStation         float64
# MaxTimeToNearestStation         float64
# FloorPlan                      category
# Area                              int64
# AreaIsGreaterFlag              category
# UnitPrice                       float64
# PricePerTsubo                   float64
# LandShape                      category
# Frontage                        float64
# FrontageIsGreaterFlag          category
# TotalFloorArea                  float64
# TotalFloorAreaIsGreaterFlag    category
# BuildingYear                   category
# PrewarBuilding                 category
# Structure                      category
# Use                            category
# Purpose                        category
# Direction                      category
# Classification                 category
# Breadth                         float64
# CityPlanning                   category
# CoverageRatio                   float64
# FloorAreaRatio                  float64
# Period                         category
# Year                           category
# Quarter                        category
# Renovation                     category
# Remarks                          object
# TradePrice                        int64
# dtype: object

# %% [markdown]
# #### Duplicados

# %%
# Duplicados
percentage_duplicates = df_train.duplicated().sum()/len(df_train)*100
print(f"Percentual de linhas duplicadas: {percentage_duplicates:.2f}%")
# Out:
# Percentual de linhas duplicadas: 0.76%

# %% [markdown]
# Como a quantidade de linhas duplicadas é pequena, vou remover essas linhas do dataset de Treino.

# %%
# Exibir o número de linhas ANTES da remoção
print(f"Número de linhas antes da remoção de duplicadas: {len(df_train)}")

# Remover linhas duplicadas
df_train.drop_duplicates(inplace=True)

# Exibir o número de linhas restantes após a remoção
print(f"Número de linhas após remoção de duplicadas: {len(df_train)}")
# Out:
# Número de linhas antes da remoção de duplicadas: 325260
# Número de linhas após remoção de duplicadas: 322796

# %% [markdown]
# #### Valores Nulos

# %%
# Plotando % de valores nulos por coluna
plot_null_percentage(df_train,'img/train_nulos.png')

# %% [markdown]
# **Política de tratamento de valores nulos:**
# - **Colunas com mais de 50% nulos:** remover do dataset.
# - **Colunas com até 50% nulos:** imputar valores usando o MICE.
#
# **Por quê escolhi o MICE?**
# - Minha primeira escolha foi o KNN.
# - Ele considera todas as colunas para estimar o valor faltante.
# - Mas a execução dele ultrapassou 13 minutos e não terminou. Resolvi stopar.
# - O MICE utiliza regressão (um algo mais simples) entre cada coluna e a coluna em tratamento. Ele 'quebra' o problema em partes menores.
# - Isso torna ele muito escalável para datasets grandes como este.

# %%
# Removendo colunas com mais de 50% nulos

# Calcular a porcentagem de valores nulos por coluna
null_percentage = df_train.isnull().mean() * 100

# Identificando colunas com mais de 50% de valores nulos
cols_to_drop = null_percentage[null_percentage > 50].index

# Removendo essas colunas do DataFrame
df_train_cleaned = df_train.drop(columns=cols_to_drop)

# %%
# Aplicar a função ao DataFrame df_train_cleaned
df_train_cleaned_mice = impute_mice_and_mode(df_train_cleaned)

# %%
# Plotando % de valores nulos após o tratamento
plot_null_percentage(df_train_cleaned_mice)

# %%
# Salvando dataset limpo e com nulos tratados:
df_train_cleaned_mice.to_csv('../data/train2_nulls_imputted.csv', index=False)

# %% [markdown]
# ### Tratamento de Outliers

# %%
df_train = pd.read_csv('../data/train2_nulls_imputted.csv')
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322796 entries, 0 to 322795
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   MunicipalityCode             322796 non-null  float64
#  1   MinTimeToNearestStation      322796 non-null  float64
#  2   MaxTimeToNearestStation      322796 non-null  float64
#  3   Area                         322796 non-null  float64
#  4   AreaIsGreaterFlag            322796 non-null  float64
#  5   Frontage                     322796 non-null  float64
#  6   TotalFloorAreaIsGreaterFlag  322796 non-null  float64
#  7   BuildingYear                 322796 non-null  float64
#  8   PrewarBuilding               322796 non-null  float64
#  9   Breadth                      322796 non-null  float64
#  10  CoverageRatio                322796 non-null  float64
#  11  FloorAreaRatio               322796 non-null  float64
#  12  Year                         322796 non-null  float64
#  13  Quarter                      322796 non-null  float64
#  14  TradePrice                   322796 non-null  float64
#  15  Type                         322796 non-null  object
#  16  Region                       322796 non-null  object
#  17  Prefecture                   322796 non-null  object
#  18  Municipality                 322796 non-null  object
#  19  DistrictName                 322796 non-null  object
#  20  NearestStation               322796 non-null  object
#  21  TimeToNearestStation         322796 non-null  object
#  22  LandShape                    322796 non-null  object
#  23  Structure                    322796 non-null  object
#  24  Use                          322796 non-null  object
#  25  Direction                    322796 non-null  object
#  26  Classification               322796 non-null  object
#  27  CityPlanning                 322796 non-null  object
#  28  Period                       322796 non-null  object
# dtypes: float64(15), object(14)
# memory usage: 71.4+ MB

# %%
# Plotar os boxplots para o DataFrame df_train para ter uma ideia da distribuição dos dados
plot_boxplots(df_train)

# %% [markdown]
# #### Outliers em TradePrice

# %%
df_train['TradePrice'].describe()
# Out:
# count        322796.0000
# mean       66445058.7836
# std       325745082.3655
# min            1000.0000
# 25%        22000000.0000
# 50%        35000000.0000
# 75%        54000000.0000
# max     61000000000.0000
# Name: TradePrice, dtype: float64

# %% [markdown]
# O valor máximo de TradePrice é de 61 **bilhões**, muito acima do percentil 75. Isso indica a presença de dados muito extremos.
#
# Vamos tentar encontrar um ponto de corte de outliers.

# %%
# Calcular e imprimir os percentis de 'TradePrice'
percentis = df_train['TradePrice'].quantile([0.90, 0.95, 0.99, 0.995])
print("Percentis de TradePrice: (milhões de yen)")
print(percentis/1000000)
# Out:
# Percentis de TradePrice: (milhões de yen)
# 0.9000     93.0000
# 0.9500    160.0000
# 0.9900    600.0000
# 0.9950   1000.0000
# Name: TradePrice, dtype: float64

# %%
df_train.shape
# Out:
# (322796, 29)

# %%
# Imprimir a quantidade de linhas acima de cada percentil
for perc in percentis.index:
    count = (df_train['TradePrice'] > percentis[perc]).sum()
    print(f"Quantidade de linhas acima do percentil {int(perc * 100)}: {count}")
# Out:
# Quantidade de linhas acima do percentil 90: 32109
# Quantidade de linhas acima do percentil 95: 16018
# Quantidade de linhas acima do percentil 99: 3218
# Quantidade de linhas acima do percentil 99: 1594

# %% [markdown]
# Para não prejudicar o modelo e, também, não perder muita informação, vou remover as linhas com preço acima do percentil 95: 16.018 linhas (5% das linhas de df_train).

# %%
# Calcular o valor do percentil 95 de 'TradePrice'
percentil_95 = df_train['TradePrice'].quantile(0.95)

# Remover as linhas com 'TradePrice' acima do percentil 95
df_train_filtered = df_train[df_train['TradePrice'] <= percentil_95]

# %%
df_train_filtered.shape
# Out:
# (306778, 29)

# %% [markdown]
# ### Avaliação de colunas

# %% [markdown]
# - Colunas redundantes: 'DistrictName', 'CityCode', 'CityName', 'PrefectureName'
# - Colunas sem variância = menor poder informativo.

# %% [markdown]
# #### Colunas sem variância

# %%
# Identificando colunas com baixa variância

# Calcular o desvio padrão de cada coluna numérica
std_devs = df_train_filtered.select_dtypes(include=['number']).std()

# Definir o threshold para o desvio padrão
threshold_std = 0.5

# Identificar colunas com desvio padrão abaixo do threshold
low_variance_cols = std_devs[std_devs < threshold_std].index

print("Colunas com desvio padrão abaixo do threshold (0.5 desvio-padrão):")
print(low_variance_cols)
# Out:
# Colunas com desvio padrão abaixo do threshold (0.5 desvio-padrão):
# Index(['AreaIsGreaterFlag', 'TotalFloorAreaIsGreaterFlag', 'PrewarBuilding'], dtype='object')

# %%
# Remover as colunas com baixa variância do DataFrame
df_train_filtered = df_train_filtered.drop(columns=low_variance_cols)

# %%
df_train_filtered.shape
# Out:
# (306778, 26)

# %% [markdown]
# #### Colunas redundantes

# %% [markdown]
# Não existe um padrão para os nomes de distritos. Para diminuir a granularidade, vamos manter apenas coluna MunicipalityCode.

# %%
# Colunas relacionadas às divisões administrativas
Area_cols = ['DistrictName', 'MunicipalityCode', 'Municipality', 'Prefecture']

# Imprime a quantidade de valores únicos por coluna
for column in Area_cols:
    print(column)
    print(df_train_filtered[column].nunique())
# Out:
# DistrictName
# 1433
# MunicipalityCode
# 59
# Municipality
# 59
# Prefecture
# 1

# %%
# Remover colunas administrativas
df_train_filtered = df_train_filtered.drop(columns=['DistrictName', 'Municipality', 'Prefecture'])

# %%
df_train_filtered.columns
# Out:
# Index(['MunicipalityCode', 'MinTimeToNearestStation',
#        'MaxTimeToNearestStation', 'Area', 'Frontage', 'BuildingYear',
#        'Breadth', 'CoverageRatio', 'FloorAreaRatio', 'Year', 'Quarter',
#        'TradePrice', 'Type', 'Region', 'NearestStation',
#        'TimeToNearestStation', 'LandShape', 'Structure', 'Use', 'Direction',
#        'Classification', 'CityPlanning', 'Period'],
#       dtype='object')

# %%
# Imprimir a quantidade de valores únicos em cada coluna
unique_counts = df_train_filtered.nunique()
print("Quantidade de valores únicos por coluna:")
print(unique_counts)
# Out:
# Quantidade de valores únicos por coluna:
# MunicipalityCode               59
# MinTimeToNearestStation       445
# MaxTimeToNearestStation       444
# Area                          154
# Frontage                   143482
# BuildingYear                58337
# Breadth                    143372
# CoverageRatio                 417
# FloorAreaRatio                427
# Year                           15
# Quarter                         4
# TradePrice                    310
# Type                            5
# Region                          4
# NearestStation                652
# TimeToNearestStation           34
# LandShape                       9
# Structure                      22
# Use                           161
# Direction                       9
# Classification                 14
# CityPlanning                   16
# Period                         57
# dtype: int64

# %%
# Encontrar colunas com menos de 60 valores únicos
low_unique_cols = df_train_filtered.columns[df_train_filtered.nunique() < 60]

# Número de gráficos
n_plots = len(low_unique_cols)
n_cols = 5
n_rows = (n_plots // n_cols) + (n_plots % n_cols > 0)  # Número de linhas necessárias

# Criar a grid de subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 4))
axes = axes.flatten()  # Achatar a matriz de eixos

# Plotar gráficos
for ax, col in zip(axes, low_unique_cols):
    df_train_filtered[col].value_counts().plot(kind='bar', ax=ax)
    ax.set_title(col)
    ax.set_ylabel('Count')
    ax.tick_params(axis='x', rotation=45)
    ax.set_xlabel(' ')  # Remover o rótulo do eixo x
    ax.set_xticks([])

# Remover eixos extras
for ax in axes[len(low_unique_cols):]:
    ax.remove()

plt.tight_layout()
plt.savefig('../img/unique_values_hist.png')
plt.show()

# %% [markdown]
# Perceba que as colunas 'Region', 'LandShape', 'Direction', 'Classification' e 'CityPlanning' têm ocorrências extremamente concentradas. Vamos estudá-las mais de perto.

# %%
import pandas as pd

# Lista das colunas de interesse
cols_of_interest = ['Region', 'LandShape', 'Direction', 'Classification', 'CityPlanning']

# Calcular e exibir as porcentagens de ocorrências
for col in cols_of_interest:
    counts = df_train_filtered[col].value_counts(normalize=True) * 100
    print(f"\nPorcentagem de ocorrências para a coluna {col}:")
    print(counts.sort_values(ascending=False))
# Out:
# Porcentagem de ocorrências para a coluna Region:
# Region
# Residential Area             95.7204
# Commercial Area               3.9348
# Industrial Area               0.2233
# Potential Residential Area    0.1216
# Name: proportion, dtype: float64
#
# Porcentagem de ocorrências para a coluna LandShape:
# LandShape
# Semi-rectangular Shaped   65.9307
# Rectangular Shaped        13.0580
# Irregular Shaped           7.7744
# Semi-trapezoidal Shaped    4.0032
# Semi-square Shaped         2.7808
# Flag-shaped etc.           2.0839
# Semi-shaped                2.0272
# Trapezoidal Shaped         1.9777
# Square Shaped              0.3641
# Name: proportion, dtype: float64
#
# Porcentagem de ocorrências para a coluna Direction:
# Direction
# South            55.7726
# North             7.9618
# East              7.7421
# West              7.6586
# Southeast         5.2380
# Southwest         5.1288
# Northwest         5.0975
# Northeast         4.7732
# No facing road    0.6275
# Name: proportion, dtype: float64
#
# Porcentagem de ocorrências para a coluna Classification:
# Classification
# Ward Road                       68.8941
# Private Road                    13.8282
# City Road                       12.9745
# Tokyo Metropolitan Road          1.8179
# Road                             1.4587
# Town Road                        0.3791
# National Highway                 0.2647
# Access Road                      0.2070
# Village Road                     0.0789
# Agricultural Road                0.0306
# Prefectural Road                 0.0238
# Forest Road                      0.0202
# Hokkaido Prefectural Road        0.0186
# Kyoto/ Osaka Prefectural Road    0.0036
# Name: proportion, dtype: float64
#
# Porcentagem de ocorrências para a coluna CityPlanning:
# CityPlanning
# Category I Exclusively Low-story Residential Zone      25.6361
# Commercial Zone                                        17.5625
# Category I Exclusively Medium-high Residential Zone    14.3498
# Quasi-industrial Zone                                  13.9808
# Category I Residential Zone                            10.9154
# Neighborhood Commercial Zone                            9.3263
# Category II Exclusively Medium-high Residential Zone    2.4337
# Category II Residential Zone                            1.9376
# Industrial Zone                                         1.3759
# Quasi-residential Zone                                  1.3270
# Category II Exclusively Low-story Residential Zone      0.7302
# Urbanization Control Area                               0.1718
# Non-divided City Planning Area                          0.1692
# Exclusively Industrial Zone                             0.0414
# Outside City Planning Area                              0.0404
# Quasi-city Planning Area                                0.0020
# Name: proportion, dtype: float64

# %% [markdown]
# Vamos remover as linhas com pouquíssimas ocorrências:

# %%
# Lista das colunas de interesse
cols_of_interest = ['Region', 'LandShape', 'Direction', 'Classification', 'CityPlanning']

# Criar uma cópia do DataFrame para não modificar o original
df_filtered = df_train_filtered.copy()

# Remover linhas com valores que ocorrem menos de 2% das vezes
for col in cols_of_interest:
    # Calcular as porcentagens de ocorrências
    counts = df_filtered[col].value_counts(normalize=True) * 100
    
    # Identificar os valores a serem removidos (ocorrem menos de 2%)
    values_to_remove = counts[counts < 2].index
    
    # Remover as linhas com esses valores
    df_filtered = df_filtered[~df_filtered[col].isin(values_to_remove)]

# %%
df_train_filtered.shape
# Out:
# (306778, 23)

# %%
df_filtered.shape
# Out:
# (275058, 23)

# %% [markdown]
# Por fim, vamos remover as últimas colunas redundantes:
# - TimeToNearestStation: desnecessária porque já temos colunas com tempo mínimo e máximo.
# - Period: desnecessária porque já temos colunas com o ano e trimestre.

# %%
df_filtered = df_filtered.drop(columns=['TimeToNearestStation', 'Period'])

# %%
df_filtered.shape
# Out:
# (275058, 21)

# %% [markdown]
# Salvando o dataframe limpo e pré-processado:

# %%
# Salvando em csv
df_filtered.to_csv('../data/train3_less_columns.csv', index=False)

# Salvando no banco SQL
# Conectar ao banco de dados SQLite (ou criar se não existir)
conn = sqlite3.connect('../data/house_prices.db')

# Gravar o DataFrame no banco de dados
df_filtered.to_sql('df_train_cleaned', conn, if_exists='replace', index=False)

# Fechar a conexão
conn.close()

# %% [markdown]
# ## Analisando Padrões

# %%
df_filtered = pd.read_csv('../data/train3_less_columns.csv')

# %% [markdown]
# ### Colunas Numéricas

# %%
# Selecionar colunas numéricas
numeric_cols = df_filtered.select_dtypes(include=['number']).columns

# Definir o número de linhas necessárias para a grid
n_cols = 3
n_rows = (len(numeric_cols) + n_cols - 1) // n_cols  # Calcula o número de linhas necessárias

# Criar a figura e os eixos para o grid
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows), constrained_layout=True)

# Achatar a matriz de eixos para iteração
axs = axs.flatten()

# Plotar histogramas para cada coluna numérica
for i, col in enumerate(numeric_cols):
    axs[i].hist(df_filtered[col].dropna(), bins=30, edgecolor='black')
    axs[i].set_title(col)
    axs[i].set_xlabel('Value')
    axs[i].set_ylabel('Frequency')

# Ocultar eixos extras, se houver
for j in range(len(numeric_cols), len(axs)):
    axs[j].axis('off')

plt.tight_layout()
plt.savefig('../img/dist_num_cols.png')
plt.show()
# Out:
# /tmp/ipykernel_171795/1923343043.py:25: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# Correlações

# %%
# Selecionar apenas as colunas numéricas de df_filtered
numeric_columns = df_filtered.select_dtypes(include=['number'])

# Calcular a matriz de correlação
correlation_matrix = numeric_columns.corr()

# Configurar o tamanho da figura
plt.figure(figsize=(9, 5))

# Plotar o heatmap de correlação
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Título do gráfico
plt.title('Heatmap de Correlação das Colunas Numéricas')

# Exibir o gráfico
plt.tight_layout()
plt.savefig('../img/correlation.png')
plt.show()
plt.close()

# %% [markdown]
# **Insights:**
# 1. A maioria dos imóveis são baratos = distribuição de TradePrice com cauda longa à direita (*right skew*). Será necessário transformar essa coluna (ex: transformação log) antes de usá-la em modelos, para deixá-la mais simétrica.
# 2. A maioria dos imóveis foi construída no início dos anos 2000 = não são antigos.
# 3. Não há muita variação de fachada (Frontage), área (Area) ou largura (Breadth) dos imóveis.
# 4. A maioria dos imóveis está a menos de 20 min da estação mais próxima.
# 5. O ano com mais transações foi 2013; com menos, em 2005.
# 6. Os imóveis são pequenos: a área mediana é 70m², a área mediana da fachada é 7m² e a largura mediana é 6m.
# 7. O tempo máximo e mínimo até a estação mais próxima é praticamente igual = posso remover uma dessas colunas. Vou remover a coluna de tempo mínimo.
# 8. **As métricas com maior correlação com o preço são a ÁREA do imóvel e o seu ANO DE CONSTRUÇÃO.**

# %% [markdown]
# ### Colunas Categóricas

# %%
non_numeric_cols = df_filtered.select_dtypes(include=['object', 'category']).columns

# Contar ocorrências e plotar gráficos
for col in non_numeric_cols:
    counts = df_filtered[col].value_counts(normalize=False)  # Contagem absoluta
    plt.figure(figsize=(9, 5))
    counts.plot(kind='bar')
    plt.title(f'Contagem de Ocorrências para {col}')
    plt.xlabel(col)
    plt.ylabel('Quantidade')
    plt.xticks(rotation=45, ha='right')  # Ajuste a rotação dos rótulos do eixo x para melhor leitura
    plt.tight_layout()  # Ajusta o layout para evitar sobreposição
    plt.show()

# %% [markdown]
# **Insights:**
# 1. A maioria dos imóveis são condomínios.
# 2. Quase não existem ocorrências de imóveis do tipo 'Forest Land' e 'Agricultural Land' = vou removê-los.
# 3. Quase todos os imóveis estão em áreas residenciais.
# 4. A fachada da maioria está voltada para o sul.
# 5. A maioria tem estrutura de concreto, madeira ou aço.

# %% [markdown]
# ## Ajustes Finais

# %% [markdown]
# ### Remover colunas

# %%
df_filtered.columns
# Out:
# Index(['MunicipalityCode', 'MinTimeToNearestStation',
#        'MaxTimeToNearestStation', 'Area', 'Frontage', 'BuildingYear',
#        'Breadth', 'CoverageRatio', 'FloorAreaRatio', 'Year', 'Quarter',
#        'TradePrice', 'Type', 'Region', 'NearestStation', 'LandShape',
#        'Structure', 'Use', 'Direction', 'Classification', 'CityPlanning'],
#       dtype='object')

# %%
df_filtered = df_filtered.drop(columns='MinTimeToNearestStation')

# %% [markdown]
# ### Remover linhas

# %%
# Remove imóveis do tipo Forest Land ou Agricultural Land
df_filtered = df_filtered[~df_filtered['Type'].isin(['Forest Land', 'Agricultural Land'])]

# Remove imóveis na região Comercial Area
df_filtered = df_filtered[df_filtered['Region'] != 'Commercial Area']

# Filtra e mantém apenas os valores especificados na coluna 'Structure'
valid_structures = ['RC', 'W', 'SRC', 'S', 'LS']
df_filtered = df_filtered[df_filtered['Structure'].isin(valid_structures)]

# %% [markdown]
# ### Ajustar TradePrice
#
# Transformação log para deixar a distribuição mais simétrica.

# %%
# Cria a coluna 'TradePrice_log' com a transformação logarítmica
df_filtered['TradePrice_log'] = np.log(df_filtered['TradePrice'])

# Plotar histogramas antes e depois da transformação
plt.figure(figsize=(9, 5))

# Histograma da coluna original (antes da transformação)
plt.subplot(1, 2, 1)
plt.hist(df_filtered['TradePrice'], bins=30, color='blue', edgecolor='black')
plt.title('Histograma de TradePrice (Original)')
plt.xlabel('TradePrice')
plt.ylabel('Frequência')

# Histograma da transformação logarítmica
plt.subplot(1, 2, 2)
plt.hist(df_filtered['TradePrice_log'], bins=30, color='green', edgecolor='black')
plt.title('Histograma de TradePrice (Transformação Log)')
plt.xlabel('TradePrice (Log)')
plt.ylabel('Frequência')

plt.tight_layout()
plt.savefig('../img/trade_price_log.png')
plt.show()
plt.close()

# Remover a coluna 'TradePrice' original
df_filtered = df_filtered.drop(columns=['TradePrice'])

# %% [markdown]
# ## Salvando o dataset completamente preparado

# %%
# Salvando em csv
df_filtered.to_csv('../data/train3_cleaned.csv', index=False)

# Salvando no banco SQL
# Conectar ao banco de dados SQLite (ou criar se não existir)
conn = sqlite3.connect('../data/house_prices.db')

# Gravar o DataFrame no banco de dados
df_filtered.to_sql('df_train_cleaned', conn, if_exists='replace', index=False)

# Fechar a conexão
conn.close()
